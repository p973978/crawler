# %%
import requests
import urllib as request
headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36'}
url = 'https://www.dcard.tw/service/api/v2/forums/photography/posts?limit=30&before=233539423'
res = requests.get(url, headers=headers)
print(res.text)
# Out:
# [{"id":233539045,"title":"#單眼 一些北宜的追焦","excerpt":"在前幾個星期終於入手了人生第一台相機，雖然是一台二手的相機，也稱不上頂規機種，但目前來說已經心滿意足了ಠ‿ಠ，接下來就是一些照片，構圖的部分可能還要好好拿捏才行，而且最近狂下雨，真的很難上山練習，話說","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"d0cd5819-4627-4b5f-8a8e-050976e0fba1","replyId":null,"createdAt":"2020-04-23T17:23:18.738Z","updatedAt":"2020-04-23T17:24:56.964Z","commentCount":18,"likeCount":7,"withNickname":false,"tags":[],"topics":["北宜","單眼","攝影作品","攝影"],"meta":{"layout":"classic"},"forumName":"攝影","forumAlias":"photography","nsfw":false,"gender":"M","school":"國立體育大學","replyTitle":null,"reportReason":"","mediaMeta":[{"id":"8867c83b-ae02-4bc0-ba8b-e5891222454e","url":"https://i.imgur.com/Ob1Sp3dl.jpg","normalizedUrl":"https://i.imgur.com/Ob1Sp3dl.jpg","thumbnail":"https://i.imgur.com/Ob1Sp3dl.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2020-04-23T17:23:18.738Z","updatedAt":"2020-04-23T17:24:56.964Z"},{"id":"8867c83b-ae02-4bc0-ba8b-e5891222454e","url":"https://i.imgur.com/Ob1Sp3d.jpg","normalizedUrl":"https://imgur.com/Ob1Sp3d","thumbnail":"https://i.imgur.com/Ob1Sp3dl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2020-04-23T17:23:18.738Z","updatedAt":"2020-04-23T17:24:56.964Z"},{"id":"e130e02f-8774-4097-af53-a3b13bfb5b76","url":"https://i.imgur.com/8IYnJGQ.jpg","normalizedUrl":"https://imgur.com/8IYnJGQ","thumbnail":"https://i.imgur.com/8IYnJGQl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2020-04-23T17:23:18.738Z","updatedAt":"2020-04-23T17:24:56.964Z"},{"id":"e0814592-33a1-4bef-9064-678a4ca317a9","url":"https://i.imgur.com/nFEgxHo.jpg","normalizedUrl":"https://imgur.com/nFEgxHo","thumbnail":"https://i.imgur.com/nFEgxHol.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2020-04-23T17:23:18.738Z","updatedAt":"2020-04-23T17:24:56.964Z"},{"id":"7e188a12-a077-4d7f-851f-6390c45c58fd","url":"https://i.imgur.com/shbcjWj.jpg","normalizedUrl":"https://imgur.com/shbcjWj","thumbnail":"https://i.imgur.com/shbcjWjl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2020-04-23T17:23:18.738Z","updatedAt":"2020-04-23T17:24:56.964Z"}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":7}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":false,"media":[{"url":"https://i.imgur.com/Ob1Sp3d.jpg"},{"url":"https://i.imgur.com/8IYnJGQ.jpg"},{"url":"https://i.imgur.com/nFEgxHo.jpg"},{"url":"https://i.imgur.com/shbcjWj.jpg"}],"reportReasonText":"","elapsedTime":547803,"postAvatar":""},{"id":233538944,"title":"台北的街道（1）","excerpt":"帶著相機穿梭在巷弄中 尋找一個自己的角度","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"d0cd5819-4627-4b5f-8a8e-050976e0fba1","replyId":null,"createdAt":"2020-04-23T17:09:16.202Z","updatedAt":"2020-04-25T04:43:17.630Z","commentCount":7,"likeCount":9,"withNickname":true,"tags":["HIDE_THUMBNAIL"],"topics":["攝影作品","街道","台北","相機"],"meta":{"layout":"classic"},"forumName":"攝影","forumAlias":"photography","nsfw":false,"gender":"M","school":"Ronaldo_Liu","department":"ronaldoliu","replyTitle":null,"reportReason":"","mediaMeta":[{"id":"972b3b24-077c-435b-8102-52d3e914eeeb","url":"https://megapx-assets.dcard.tw/images/3a982968-d637-4612-a56b-6f180cbe0b82/640.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/3a982968-d637-4612-a56b-6f180cbe0b82","thumbnail":"https://megapx-assets.dcard.tw/images/3a982968-d637-4612-a56b-6f180cbe0b82/160.jpeg","type":"image/megapx","tags":["ANNOTATED"],"createdAt":"2020-04-23T17:09:16.202Z","updatedAt":"2020-04-25T04:43:17.630Z","width":1080,"height":1616},{"id":"e05d8e76-618e-4765-b485-f834fd32f829","url":"https://megapx-assets.dcard.tw/images/fbf0ee88-e88a-460f-871c-450d635d872a/640.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/fbf0ee88-e88a-460f-871c-450d635d872a","thumbnail":"https://megapx-assets.dcard.tw/images/fbf0ee88-e88a-460f-871c-450d635d872a/160.jpeg","type":"image/megapx","tags":["ANNOTATED"],"createdAt":"2020-04-23T17:09:16 ...

# %%
import json

json_str = res.text
json_data = json.loads(json_str)

# %%
type(json_data)#最外層是 list,內層才是dictionary

json_data.__len__() #只能爬30篇文章
print(json_data)
# Out:
# [{'id': 233539045, 'title': '#單眼 一些北宜的追焦', 'excerpt': '在前幾個星期終於入手了人生第一台相機，雖然是一台二手的相機，也稱不上頂規機種，但目前來說已經心滿意足了ಠ‿ಠ，接下來就是一些照片，構圖的部分可能還要好好拿捏才行，而且最近狂下雨，真的很難上山練習，話說', 'anonymousSchool': False, 'anonymousDepartment': True, 'pinned': False, 'forumId': 'd0cd5819-4627-4b5f-8a8e-050976e0fba1', 'replyId': None, 'createdAt': '2020-04-23T17:23:18.738Z', 'updatedAt': '2020-04-23T17:24:56.964Z', 'commentCount': 18, 'likeCount': 7, 'withNickname': False, 'tags': [], 'topics': ['北宜', '單眼', '攝影作品', '攝影'], 'meta': {'layout': 'classic'}, 'forumName': '攝影', 'forumAlias': 'photography', 'nsfw': False, 'gender': 'M', 'school': '國立體育大學', 'replyTitle': None, 'reportReason': '', 'mediaMeta': [], 'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 7}], 'hidden': False, 'customStyle': None, 'isSuspiciousAccount': False, 'layout': 'classic', 'withImages': True, 'withVideos': False, 'media': [{'url': 'https://i.imgur.com/Ob1Sp3d.jpg'}, {'url': 'https://i.imgur.com/8IYnJGQ.jpg'}, {'url': 'https://i.imgur.com/nFEgxHo.jpg'}, {'url': 'https://i.imgur.com/shbcjWj.jpg'}], 'reportReasonText': '', 'elapsedTime': 546435, 'postAvatar': ''}, {'id': 233538944, 'title': '台北的街道（1）', 'excerpt': '帶著相機穿梭在巷弄中 尋找一個自己的角度', 'anonymousSchool': False, 'anonymousDepartment': False, 'pinned': False, 'forumId': 'd0cd5819-4627-4b5f-8a8e-050976e0fba1', 'replyId': None, 'createdAt': '2020-04-23T17:09:16.202Z', 'updatedAt': '2020-04-25T04:43:17.630Z', 'commentCount': 7, 'likeCount': 9, 'withNickname': True, 'tags': ['HIDE_THUMBNAIL'], 'topics': ['攝影作品', '街道', '台北', '相機'], 'meta': {'layout': 'classic'}, 'forumName': '攝影', 'forumAlias': 'photography', 'nsfw': False, 'gender': 'M', 'school': 'Ronaldo_Liu', 'department': 'ronaldoliu', 'replyTitle': None, 'reportReason': '', 'mediaMeta': [], 'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 9}], 'hidden': False, 'customStyle': None, 'isSuspiciousAccount': False, 'layout': 'classic', 'withImages': True, 'withVideos': False, 'media': [], 'reportReasonText': '', 'elapsedTime': 547277, 'postAvatar': ''}, {'id': 233538891, 'title': 'Fuji 250d', 'excerpt': '純分享，大部分在淡水 士林拍攝，底片很美', 'anonymousSchool': False, 'anonymousDepartment': False, 'pinned': False, 'forumId': 'd0cd5819-4627-4b5f-8a8e-050976e0fba1', 'replyId': None, 'createdAt': '2020-04-23T17:00:56.391Z', 'updatedAt': '2020-04-23T17:00:56.391Z', 'commentCount': 1, 'likeCount': 3, 'withNickname': True, 'tags': [], 'topics': ['攝影作品', '攝影', '底片', '街拍', '風景'], 'meta': {'layout': 'classic'}, 'forumName': '攝影', 'forumAlias': 'photography', 'nsfw': False, 'gender': 'M', 'school': '塔克', 'department': 'intheart0505', 'replyTitle': None, 'reportReason': '', 'mediaMeta': [], 'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 3}], 'hidden': False, 'customStyle': None, 'isSuspiciousAccount': False, 'layout': 'classic', 'withImages': True, 'withVideos': False, 'media': [{'url': 'https://megapx-assets.dcard.tw/images/35f19646-a718-45d4-943d-18da1dc05777/640.jpeg'}, {'url': 'https://megapx-assets.dcard.tw/images/a78ce99b-7ad5-492a-835a-77d8c3b382e7/640.jpeg'}, {'url': 'https://megapx-assets.dcard.tw/images/1124a52f-5666-462f-840b-1b67453f7ee5/640.jpeg'}, {'url': 'https://megapx-assets.dcard.tw/images/70465f5c-5d32-4924-870c-5f19b270b8a3/640.jpeg'}, {'url': 'https://megapx-assets.dcard.tw/images/28e709e3-e52e-4c6c-8908-8ab05a3b0c5a/640.jpeg'}, {'url': 'https://megapx-assets.dcard.tw/images/a4cf6b3e-e4d3-445b-88d2-2bebd1afe2fd/640.jpeg'}, {'url': 'https://megapx-assets.dcard.tw/images/13240dd4-d22f-4670-8795-bc5ef49ec76d/640.jpeg'}], 'reportReasonText': '', 'elapsedTime': 547777, 'postAvatar': ''}, {'id': 233538622, 'title': '手機一拿起 照片送給你', 'excerpt': '分享最近還算滿意的照片，拍的不好請鞭小力點，——————————————，夕陽街景，南投清境天空步道旁的flowers，台北樂活公園，新莊中港大排，台中彩虹眷村，嘉義阿里山隙頂日出，台中大坑步道，台中', 'anonymousSchool': False, 'anonymousDepartment': True, 'pinned': False, 'forumId': 'd0cd5819-4627-4b5f-8a8e-050976e0fba1', 'replyId': None, 'createdAt': '2020-04-23T16:25:30.680Z', 'updatedAt': '2020-04-23T16:2 ...

# %%
for k in json_data[0]:
    print(k)
# dictionary
# Out:
# id
# title
# excerpt
# anonymousSchool
# anonymousDepartment
# pinned
# forumId
# replyId
# createdAt
# updatedAt
# commentCount
# likeCount
# withNickname
# tags
# topics
# meta
# forumName
# forumAlias
# nsfw
# gender
# school
# replyTitle
# reportReason
# mediaMeta
# reactions
# hidden
# customStyle
# isSuspiciousAccount
# layout
# withImages
# withVideos
# media
# reportReasonText
# elapsedTime
# postAvatar

# %%
json_data[0]['mediaMeta']
# Out:
# []
